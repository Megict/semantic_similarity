# %%
import codecs

# %%
i = 0

# %%
with codecs.open(f"{i}.txt", "w", encoding = "utf-8") as f:
    with codecs.open("input.txt", "r", encoding = "utf-8") as fi:
        input = fi.read()
    text_ = input
    f.write(text_)
i += 1
print(i)
# Out:
# 25

# %%
#00 84
